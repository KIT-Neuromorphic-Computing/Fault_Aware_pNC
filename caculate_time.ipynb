# %%
datasets = ['acuteinflammation',
            'balancescale',
            'breastcancerwisc',
            'cardiotocography3clases',
            'energyy1',
            'energyy2',
            'iris',
            'mammographic',
            'pendigits',
            'seeds',
            'tictactoe',
            'vertebralcolumn2clases',
            'vertebralcolumn3clases']

# %%
len(datasets)
# Out:
# 13

# %%
import re
import os
import glob

def calculate_total_training_time(log_file_path):
    """
    Reads the log file, finds lines with 'Epoch: X' and 'Epoch time: Y',
    and computes total training time *assuming* 'Epoch time: Y' is
    the average time per epoch for the last (X - previous_epoch) epochs.
    """
    total_time = 0.0
    # This regex looks for a line containing something like:
    # | Epoch:    50 | Train loss: ... | Epoch time: 0.2 |
    pattern = re.compile(r'\|\s*Epoch:\s*(\d+)\s*\|.*Epoch time:\s+([\d.]+)')
    
    prev_epoch = None
    with open(log_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            match = pattern.search(line)
            if match:
                current_epoch = int(match.group(1))
                epoch_time_avg = float(match.group(2))  # average time per epoch (assumed)
                
                if prev_epoch is None:
                    # For the very first logged epoch, assume that the block covers all epochs from 0 up to current_epoch
                    block_size = current_epoch + 1  # e.g., epoch=50 implies epochs 0..50 inclusive => 51 epochs
                else:
                    # Otherwise, the block covers (prev_epoch+1) .. current_epoch
                    block_size = current_epoch - prev_epoch
                
                # Multiply average time by the block size
                total_time += epoch_time_avg * block_size
                prev_epoch = current_epoch

    return total_time

if __name__ == "__main__":
    results = []  # This will hold our results
    baseline_total_array = []
    acts = ['tanh', 'relu', 'sigmoid', 'cr', 'none',]
    types = ['Normal', 'Robust', 'Mixed',]
    for a in acts:
        for t in types:
            for j, ds in enumerate(datasets):
                total = 0
                for i in range(0,10):
                    log_path = f'./{a}_10_FaultAnalysis{t}/log/data_{j:02}_{ds}_seed_{i:02d}_*.log'
                    matching_files = glob.glob(log_path)
                    if len(matching_files) == 0:
                        print(f"Log file not found: {log_path}")
                        continue
                    log_path = matching_files[0]
                    total_training_time = calculate_total_training_time(log_path)  # Use your function here
                    total += total_training_time
                baseline_total_array.append(total)
                minutes = int((total % 3600) // 60)
                seconds = total % 60
                days = int(total // 86400)
                hours = int((total % 86400) // 3600)
                results.append({
                    f'{t}_{a}': total,
                    # 'type': t,
                    'dataset': ds,
                    'total_seconds': total,
                    # 'days': days,
                    # 'hours': hours,
                    # 'minutes': minutes,
                    # 'seconds': seconds
                })
                print(f"Total training time for {ds} [{a}, {t}]: {days} days, {hours} hours, {minutes} minutes and {seconds:.2f} seconds")
# Out:
# Total training time for acuteinflammation [tanh, Normal]: 0 days, 8 hours, 54 minutes and 25.70 seconds
# Total training time for balancescale [tanh, Normal]: 0 days, 8 hours, 25 minutes and 30.30 seconds
# Total training time for breastcancerwisc [tanh, Normal]: 0 days, 9 hours, 54 minutes and 36.80 seconds
# Total training time for cardiotocography3clases [tanh, Normal]: 0 days, 14 hours, 19 minutes and 36.30 seconds
# Total training time for energyy1 [tanh, Normal]: 0 days, 10 hours, 44 minutes and 39.20 seconds
# Total training time for energyy2 [tanh, Normal]: 0 days, 10 hours, 39 minutes and 55.10 seconds
# Total training time for iris [tanh, Normal]: 0 days, 8 hours, 23 minutes and 29.40 seconds
# Total training time for mammographic [tanh, Normal]: 0 days, 9 hours, 5 minutes and 1.00 seconds
# Total training time for pendigits [tanh, Normal]: 0 days, 16 hours, 9 minutes and 20.80 seconds
# Total training time for seeds [tanh, Normal]: 0 days, 9 hours, 29 minutes and 44.60 seconds
# Total training time for tictactoe [tanh, Normal]: 0 days, 10 hours, 52 minutes and 31.30 seconds
# Total training time for vertebralcolumn2clases [tanh, Normal]: 0 days, 8 hours, 54 minutes and 5.20 seconds
# Total training time for vertebralcolumn3clases [tanh, Normal]: 0 days, 7 hours, 43 minutes and 44.00 seconds
# Total training time for acuteinflammation [tanh, Robust]: 0 days, 9 hours, 37 minutes and 20.40 seconds
# Total training time for balancescale [tanh, Robust]: 0 days, 8 hours, 40 minutes and 58.50 seconds
# Total training time for breastcancerwisc [tanh, Robust]: 0 days, 11 hours, 11 minutes and 14.60 seconds
# Total training time for cardiotocography3clases [tanh, Robust]: 0 days, 14 hours, 35 minutes and 37.50 seconds
# Total training time for energyy1 [tanh, Robust]: 0 days, 11 hours, 15 minutes and 17.30 seconds
# Total training time for energyy2 [tanh, Robust]: 0 days, 11 hours, 6 minutes and 25.40 seconds
# Total training time for iris [tanh, Robust]: 0 days, 8 hours, 5 minutes and 8.10 seconds
# Total training time for mammographic [tanh, Robust]: 0 days, 8 hours, 1 minutes and 11.50 seconds
# Total training time for pendigits [tanh, Robust]: 0 days, 21 hours, 4 minutes and 18.10 seconds
# Total training time for seeds [tanh, Robust]: 0 days, 9 hours, 37 minutes and 7.90 seconds
# Total training time for tictactoe [tanh, Robust]: 0 days, 10 hours, 22 minutes and 11.50 seconds
# Total training time for vertebralcolumn2clases [tanh, Robust]: 0 days, 9 hours, 16 minutes and 36.20 seconds
# Total training time for vertebralcolumn3clases [tanh, Robust]: 0 days, 7 hours, 18 minutes and 25.00 seconds
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_00_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_01_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_02_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_03_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_04_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_05_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_06_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_07_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_08_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_09_*.log
# Total training time for acuteinflammation [tanh, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_01_balancescale_seed_00_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_01_balancescale_seed_01_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_01_balancescale_seed_02_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_01_balancescale_seed_03_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_01_balancescale_seed_04_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_01_balancescale_seed_05_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_01_balancescale_seed_06_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_01_balancescale_seed_07_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_01_balancescale_seed_08_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_01_balancescale_seed_09_*.log
# Total training time for balancescale [tanh, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_00_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_01_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_02_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_03_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_04_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_05_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_06_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_07_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_08_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_09_*.log
# Total training time for breastcancerwisc [tanh, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_00_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_01_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_02_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_03_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_04_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_05_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_06_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_07_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_08_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_09_*.log
# Total training time for cardiotocography3clases [tanh, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_04_energyy1_seed_00_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_04_energyy1_seed_01_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_04_energyy1_seed_02_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_04_energyy1_seed_03_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_04_energyy1_seed_04_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_04_energyy1_seed_05_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_04_energyy1_seed_06_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_04_energyy1_seed_07_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_04_energyy1_seed_08_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_04_energyy1_seed_09_*.log
# Total training time for energyy1 [tanh, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_05_energyy2_seed_00_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_05_energyy2_seed_01_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_05_energyy2_seed_02_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_05_energyy2_seed_03_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_05_energyy2_seed_04_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_05_energyy2_seed_05_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_05_energyy2_seed_06_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_05_energyy2_seed_07_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_05_energyy2_seed_08_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_05_energyy2_seed_09_*.log
# Total training time for energyy2 [tanh, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_06_iris_seed_00_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_06_iris_seed_01_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_06_iris_seed_02_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_06_iris_seed_03_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_06_iris_seed_04_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_06_iris_seed_05_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_06_iris_seed_06_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_06_iris_seed_07_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_06_iris_seed_08_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_06_iris_seed_09_*.log
# Total training time for iris [tanh, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_07_mammographic_seed_00_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_07_mammographic_seed_01_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_07_mammographic_seed_02_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_07_mammographic_seed_03_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_07_mammographic_seed_04_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_07_mammographic_seed_05_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_07_mammographic_seed_06_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_07_mammographic_seed_07_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_07_mammographic_seed_08_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_07_mammographic_seed_09_*.log
# Total training time for mammographic [tanh, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_08_pendigits_seed_00_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_08_pendigits_seed_01_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_08_pendigits_seed_02_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_08_pendigits_seed_03_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_08_pendigits_seed_04_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_08_pendigits_seed_05_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_08_pendigits_seed_06_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_08_pendigits_seed_07_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_08_pendigits_seed_08_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_08_pendigits_seed_09_*.log
# Total training time for pendigits [tanh, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_09_seeds_seed_00_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_09_seeds_seed_01_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_09_seeds_seed_02_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_09_seeds_seed_03_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_09_seeds_seed_04_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_09_seeds_seed_05_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_09_seeds_seed_06_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_09_seeds_seed_07_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_09_seeds_seed_08_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_09_seeds_seed_09_*.log
# Total training time for seeds [tanh, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_00_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_01_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_02_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_03_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_04_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_05_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_06_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_07_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_08_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_09_*.log
# Total training time for tictactoe [tanh, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_00_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_01_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_02_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_03_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_04_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_05_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_06_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_07_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_08_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_09_*.log
# Total training time for vertebralcolumn2clases [tanh, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_00_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_01_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_02_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_03_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_04_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_05_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_06_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_07_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_08_*.log
# Log file not found: ./tanh_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_09_*.log
# Total training time for vertebralcolumn3clases [tanh, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Total training time for acuteinflammation [relu, Normal]: 0 days, 10 hours, 15 minutes and 41.20 seconds
# Total training time for balancescale [relu, Normal]: 0 days, 10 hours, 5 minutes and 23.40 seconds
# Total training time for breastcancerwisc [relu, Normal]: 0 days, 13 hours, 56 minutes and 53.80 seconds
# Total training time for cardiotocography3clases [relu, Normal]: 0 days, 18 hours, 13 minutes and 48.10 seconds
# Total training time for energyy1 [relu, Normal]: 0 days, 13 hours, 29 minutes and 7.20 seconds
# Total training time for energyy2 [relu, Normal]: 0 days, 13 hours, 9 minutes and 51.30 seconds
# Total training time for iris [relu, Normal]: 0 days, 10 hours, 9 minutes and 6.20 seconds
# Total training time for mammographic [relu, Normal]: 0 days, 10 hours, 17 minutes and 3.70 seconds
# Total training time for pendigits [relu, Normal]: 0 days, 21 hours, 18 minutes and 33.00 seconds
# Total training time for seeds [relu, Normal]: 0 days, 11 hours, 20 minutes and 21.80 seconds
# Total training time for tictactoe [relu, Normal]: 0 days, 11 hours, 36 minutes and 5.70 seconds
# Total training time for vertebralcolumn2clases [relu, Normal]: 0 days, 11 hours, 12 minutes and 18.60 seconds
# Total training time for vertebralcolumn3clases [relu, Normal]: 0 days, 9 hours, 12 minutes and 56.00 seconds
# Total training time for acuteinflammation [relu, Robust]: 0 days, 10 hours, 26 minutes and 47.40 seconds
# Total training time for balancescale [relu, Robust]: 0 days, 11 hours, 14 minutes and 52.40 seconds
# Total training time for breastcancerwisc [relu, Robust]: 0 days, 14 hours, 49 minutes and 31.60 seconds
# Total training time for cardiotocography3clases [relu, Robust]: 0 days, 18 hours, 16 minutes and 3.00 seconds
# Total training time for energyy1 [relu, Robust]: 0 days, 14 hours, 16 minutes and 17.70 seconds
# Total training time for energyy2 [relu, Robust]: 0 days, 14 hours, 12 minutes and 15.50 seconds
# Total training time for iris [relu, Robust]: 0 days, 10 hours, 57 minutes and 44.50 seconds
# Total training time for mammographic [relu, Robust]: 0 days, 10 hours, 53 minutes and 40.90 seconds
# Total training time for pendigits [relu, Robust]: 0 days, 21 hours, 1 minutes and 51.90 seconds
# Total training time for seeds [relu, Robust]: 0 days, 11 hours, 40 minutes and 22.70 seconds
# Total training time for tictactoe [relu, Robust]: 0 days, 13 hours, 44 minutes and 14.00 seconds
# Total training time for vertebralcolumn2clases [relu, Robust]: 0 days, 12 hours, 1 minutes and 23.50 seconds
# Total training time for vertebralcolumn3clases [relu, Robust]: 0 days, 9 hours, 56 minutes and 39.20 seconds
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_00_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_01_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_02_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_03_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_04_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_05_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_06_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_07_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_08_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_09_*.log
# Total training time for acuteinflammation [relu, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_01_balancescale_seed_00_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_01_balancescale_seed_01_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_01_balancescale_seed_02_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_01_balancescale_seed_03_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_01_balancescale_seed_04_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_01_balancescale_seed_05_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_01_balancescale_seed_06_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_01_balancescale_seed_07_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_01_balancescale_seed_08_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_01_balancescale_seed_09_*.log
# Total training time for balancescale [relu, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_00_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_01_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_02_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_03_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_04_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_05_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_06_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_07_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_08_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_09_*.log
# Total training time for breastcancerwisc [relu, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_00_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_01_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_02_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_03_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_04_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_05_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_06_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_07_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_08_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_09_*.log
# Total training time for cardiotocography3clases [relu, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_04_energyy1_seed_00_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_04_energyy1_seed_01_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_04_energyy1_seed_02_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_04_energyy1_seed_03_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_04_energyy1_seed_04_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_04_energyy1_seed_05_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_04_energyy1_seed_06_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_04_energyy1_seed_07_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_04_energyy1_seed_08_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_04_energyy1_seed_09_*.log
# Total training time for energyy1 [relu, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_05_energyy2_seed_00_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_05_energyy2_seed_01_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_05_energyy2_seed_02_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_05_energyy2_seed_03_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_05_energyy2_seed_04_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_05_energyy2_seed_05_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_05_energyy2_seed_06_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_05_energyy2_seed_07_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_05_energyy2_seed_08_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_05_energyy2_seed_09_*.log
# Total training time for energyy2 [relu, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_06_iris_seed_00_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_06_iris_seed_01_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_06_iris_seed_02_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_06_iris_seed_03_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_06_iris_seed_04_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_06_iris_seed_05_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_06_iris_seed_06_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_06_iris_seed_07_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_06_iris_seed_08_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_06_iris_seed_09_*.log
# Total training time for iris [relu, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_07_mammographic_seed_00_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_07_mammographic_seed_01_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_07_mammographic_seed_02_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_07_mammographic_seed_03_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_07_mammographic_seed_04_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_07_mammographic_seed_05_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_07_mammographic_seed_06_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_07_mammographic_seed_07_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_07_mammographic_seed_08_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_07_mammographic_seed_09_*.log
# Total training time for mammographic [relu, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_08_pendigits_seed_00_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_08_pendigits_seed_01_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_08_pendigits_seed_02_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_08_pendigits_seed_03_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_08_pendigits_seed_04_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_08_pendigits_seed_05_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_08_pendigits_seed_06_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_08_pendigits_seed_07_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_08_pendigits_seed_08_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_08_pendigits_seed_09_*.log
# Total training time for pendigits [relu, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_09_seeds_seed_00_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_09_seeds_seed_01_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_09_seeds_seed_02_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_09_seeds_seed_03_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_09_seeds_seed_04_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_09_seeds_seed_05_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_09_seeds_seed_06_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_09_seeds_seed_07_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_09_seeds_seed_08_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_09_seeds_seed_09_*.log
# Total training time for seeds [relu, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_00_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_01_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_02_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_03_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_04_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_05_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_06_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_07_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_08_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_09_*.log
# Total training time for tictactoe [relu, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_00_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_01_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_02_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_03_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_04_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_05_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_06_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_07_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_08_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_09_*.log
# Total training time for vertebralcolumn2clases [relu, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_00_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_01_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_02_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_03_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_04_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_05_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_06_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_07_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_08_*.log
# Log file not found: ./relu_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_09_*.log
# Total training time for vertebralcolumn3clases [relu, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Total training time for acuteinflammation [sigmoid, Normal]: 0 days, 7 hours, 41 minutes and 52.70 seconds
# Total training time for balancescale [sigmoid, Normal]: 0 days, 8 hours, 9 minutes and 57.90 seconds
# Total training time for breastcancerwisc [sigmoid, Normal]: 0 days, 9 hours, 15 minutes and 16.00 seconds
# Total training time for cardiotocography3clases [sigmoid, Normal]: 0 days, 15 hours, 43 minutes and 18.30 seconds
# Total training time for energyy1 [sigmoid, Normal]: 0 days, 10 hours, 43 minutes and 59.60 seconds
# Total training time for energyy2 [sigmoid, Normal]: 0 days, 10 hours, 33 minutes and 54.30 seconds
# Total training time for iris [sigmoid, Normal]: 0 days, 7 hours, 38 minutes and 40.80 seconds
# Total training time for mammographic [sigmoid, Normal]: 0 days, 8 hours, 45 minutes and 31.10 seconds
# Total training time for pendigits [sigmoid, Normal]: 0 days, 16 hours, 36 minutes and 8.10 seconds
# Total training time for seeds [sigmoid, Normal]: 0 days, 9 hours, 4 minutes and 7.70 seconds
# Total training time for tictactoe [sigmoid, Normal]: 0 days, 8 hours, 55 minutes and 54.00 seconds
# Total training time for vertebralcolumn2clases [sigmoid, Normal]: 0 days, 8 hours, 59 minutes and 32.80 seconds
# Total training time for vertebralcolumn3clases [sigmoid, Normal]: 0 days, 7 hours, 50 minutes and 45.00 seconds
# Total training time for acuteinflammation [sigmoid, Robust]: 0 days, 8 hours, 7 minutes and 16.10 seconds
# Total training time for balancescale [sigmoid, Robust]: 0 days, 8 hours, 8 minutes and 36.00 seconds
# Total training time for breastcancerwisc [sigmoid, Robust]: 0 days, 10 hours, 45 minutes and 18.90 seconds
# Total training time for cardiotocography3clases [sigmoid, Robust]: 0 days, 14 hours, 49 minutes and 10.70 seconds
# Total training time for energyy1 [sigmoid, Robust]: 0 days, 11 hours, 1 minutes and 38.60 seconds
# Total training time for energyy2 [sigmoid, Robust]: 0 days, 11 hours, 12 minutes and 11.10 seconds
# Total training time for iris [sigmoid, Robust]: 0 days, 8 hours, 31 minutes and 14.10 seconds
# Total training time for mammographic [sigmoid, Robust]: 0 days, 9 hours, 17 minutes and 11.80 seconds
# Total training time for pendigits [sigmoid, Robust]: 0 days, 19 hours, 17 minutes and 50.90 seconds
# Total training time for seeds [sigmoid, Robust]: 0 days, 9 hours, 12 minutes and 46.00 seconds
# Total training time for tictactoe [sigmoid, Robust]: 0 days, 9 hours, 52 minutes and 51.30 seconds
# Total training time for vertebralcolumn2clases [sigmoid, Robust]: 0 days, 8 hours, 12 minutes and 10.30 seconds
# Total training time for vertebralcolumn3clases [sigmoid, Robust]: 0 days, 7 hours, 57 minutes and 40.70 seconds
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_00_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_01_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_02_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_03_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_04_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_05_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_06_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_07_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_08_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_09_*.log
# Total training time for acuteinflammation [sigmoid, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_01_balancescale_seed_00_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_01_balancescale_seed_01_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_01_balancescale_seed_02_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_01_balancescale_seed_03_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_01_balancescale_seed_04_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_01_balancescale_seed_05_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_01_balancescale_seed_06_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_01_balancescale_seed_07_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_01_balancescale_seed_08_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_01_balancescale_seed_09_*.log
# Total training time for balancescale [sigmoid, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_00_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_01_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_02_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_03_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_04_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_05_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_06_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_07_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_08_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_09_*.log
# Total training time for breastcancerwisc [sigmoid, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_00_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_01_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_02_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_03_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_04_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_05_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_06_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_07_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_08_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_09_*.log
# Total training time for cardiotocography3clases [sigmoid, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_04_energyy1_seed_00_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_04_energyy1_seed_01_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_04_energyy1_seed_02_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_04_energyy1_seed_03_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_04_energyy1_seed_04_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_04_energyy1_seed_05_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_04_energyy1_seed_06_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_04_energyy1_seed_07_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_04_energyy1_seed_08_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_04_energyy1_seed_09_*.log
# Total training time for energyy1 [sigmoid, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_05_energyy2_seed_00_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_05_energyy2_seed_01_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_05_energyy2_seed_02_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_05_energyy2_seed_03_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_05_energyy2_seed_04_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_05_energyy2_seed_05_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_05_energyy2_seed_06_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_05_energyy2_seed_07_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_05_energyy2_seed_08_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_05_energyy2_seed_09_*.log
# Total training time for energyy2 [sigmoid, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_06_iris_seed_00_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_06_iris_seed_01_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_06_iris_seed_02_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_06_iris_seed_03_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_06_iris_seed_04_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_06_iris_seed_05_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_06_iris_seed_06_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_06_iris_seed_07_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_06_iris_seed_08_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_06_iris_seed_09_*.log
# Total training time for iris [sigmoid, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_07_mammographic_seed_00_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_07_mammographic_seed_01_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_07_mammographic_seed_02_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_07_mammographic_seed_03_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_07_mammographic_seed_04_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_07_mammographic_seed_05_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_07_mammographic_seed_06_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_07_mammographic_seed_07_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_07_mammographic_seed_08_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_07_mammographic_seed_09_*.log
# Total training time for mammographic [sigmoid, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_08_pendigits_seed_00_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_08_pendigits_seed_01_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_08_pendigits_seed_02_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_08_pendigits_seed_03_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_08_pendigits_seed_04_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_08_pendigits_seed_05_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_08_pendigits_seed_06_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_08_pendigits_seed_07_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_08_pendigits_seed_08_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_08_pendigits_seed_09_*.log
# Total training time for pendigits [sigmoid, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_09_seeds_seed_00_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_09_seeds_seed_01_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_09_seeds_seed_02_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_09_seeds_seed_03_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_09_seeds_seed_04_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_09_seeds_seed_05_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_09_seeds_seed_06_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_09_seeds_seed_07_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_09_seeds_seed_08_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_09_seeds_seed_09_*.log
# Total training time for seeds [sigmoid, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_00_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_01_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_02_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_03_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_04_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_05_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_06_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_07_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_08_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_09_*.log
# Total training time for tictactoe [sigmoid, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_00_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_01_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_02_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_03_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_04_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_05_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_06_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_07_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_08_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_09_*.log
# Total training time for vertebralcolumn2clases [sigmoid, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_00_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_01_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_02_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_03_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_04_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_05_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_06_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_07_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_08_*.log
# Log file not found: ./sigmoid_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_09_*.log
# Total training time for vertebralcolumn3clases [sigmoid, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Total training time for acuteinflammation [cr, Normal]: 0 days, 8 hours, 50 minutes and 3.80 seconds
# Total training time for balancescale [cr, Normal]: 0 days, 9 hours, 24 minutes and 45.40 seconds
# Total training time for breastcancerwisc [cr, Normal]: 0 days, 10 hours, 36 minutes and 45.50 seconds
# Total training time for cardiotocography3clases [cr, Normal]: 0 days, 17 hours, 11 minutes and 2.30 seconds
# Total training time for energyy1 [cr, Normal]: 0 days, 12 hours, 8 minutes and 56.30 seconds
# Total training time for energyy2 [cr, Normal]: 0 days, 12 hours, 27 minutes and 22.00 seconds
# Total training time for iris [cr, Normal]: 0 days, 9 hours, 59 minutes and 30.80 seconds
# Total training time for mammographic [cr, Normal]: 0 days, 8 hours, 13 minutes and 17.10 seconds
# Total training time for pendigits [cr, Normal]: 0 days, 20 hours, 44 minutes and 54.30 seconds
# Total training time for seeds [cr, Normal]: 0 days, 10 hours, 9 minutes and 56.30 seconds
# Total training time for tictactoe [cr, Normal]: 0 days, 10 hours, 15 minutes and 47.00 seconds
# Total training time for vertebralcolumn2clases [cr, Normal]: 0 days, 8 hours, 18 minutes and 1.60 seconds
# ...
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_05_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_06_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_07_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_08_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_00_acuteinflammation_seed_09_*.log
# Total training time for acuteinflammation [cr, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_01_balancescale_seed_00_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_01_balancescale_seed_01_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_01_balancescale_seed_02_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_01_balancescale_seed_03_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_01_balancescale_seed_04_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_01_balancescale_seed_05_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_01_balancescale_seed_06_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_01_balancescale_seed_07_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_01_balancescale_seed_08_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_01_balancescale_seed_09_*.log
# Total training time for balancescale [cr, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_00_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_01_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_02_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_03_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_04_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_05_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_06_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_07_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_08_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_02_breastcancerwisc_seed_09_*.log
# Total training time for breastcancerwisc [cr, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_00_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_01_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_02_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_03_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_04_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_05_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_06_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_07_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_08_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_03_cardiotocography3clases_seed_09_*.log
# Total training time for cardiotocography3clases [cr, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_04_energyy1_seed_00_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_04_energyy1_seed_01_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_04_energyy1_seed_02_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_04_energyy1_seed_03_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_04_energyy1_seed_04_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_04_energyy1_seed_05_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_04_energyy1_seed_06_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_04_energyy1_seed_07_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_04_energyy1_seed_08_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_04_energyy1_seed_09_*.log
# Total training time for energyy1 [cr, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_05_energyy2_seed_00_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_05_energyy2_seed_01_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_05_energyy2_seed_02_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_05_energyy2_seed_03_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_05_energyy2_seed_04_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_05_energyy2_seed_05_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_05_energyy2_seed_06_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_05_energyy2_seed_07_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_05_energyy2_seed_08_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_05_energyy2_seed_09_*.log
# Total training time for energyy2 [cr, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_06_iris_seed_00_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_06_iris_seed_01_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_06_iris_seed_02_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_06_iris_seed_03_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_06_iris_seed_04_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_06_iris_seed_05_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_06_iris_seed_06_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_06_iris_seed_07_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_06_iris_seed_08_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_06_iris_seed_09_*.log
# Total training time for iris [cr, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_07_mammographic_seed_00_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_07_mammographic_seed_01_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_07_mammographic_seed_02_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_07_mammographic_seed_03_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_07_mammographic_seed_04_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_07_mammographic_seed_05_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_07_mammographic_seed_06_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_07_mammographic_seed_07_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_07_mammographic_seed_08_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_07_mammographic_seed_09_*.log
# Total training time for mammographic [cr, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_08_pendigits_seed_00_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_08_pendigits_seed_01_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_08_pendigits_seed_02_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_08_pendigits_seed_03_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_08_pendigits_seed_04_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_08_pendigits_seed_05_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_08_pendigits_seed_06_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_08_pendigits_seed_07_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_08_pendigits_seed_08_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_08_pendigits_seed_09_*.log
# Total training time for pendigits [cr, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_09_seeds_seed_00_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_09_seeds_seed_01_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_09_seeds_seed_02_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_09_seeds_seed_03_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_09_seeds_seed_04_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_09_seeds_seed_05_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_09_seeds_seed_06_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_09_seeds_seed_07_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_09_seeds_seed_08_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_09_seeds_seed_09_*.log
# Total training time for seeds [cr, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_00_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_01_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_02_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_03_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_04_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_05_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_06_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_07_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_08_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_10_tictactoe_seed_09_*.log
# Total training time for tictactoe [cr, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_00_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_01_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_02_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_03_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_04_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_05_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_06_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_07_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_08_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_11_vertebralcolumn2clases_seed_09_*.log
# Total training time for vertebralcolumn2clases [cr, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_00_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_01_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_02_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_03_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_04_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_05_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_06_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_07_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_08_*.log
# Log file not found: ./cr_10_FaultAnalysisMixed/log/data_12_vertebralcolumn3clases_seed_09_*.log
# Total training time for vertebralcolumn3clases [cr, Mixed]: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Total training time for acuteinflammation [none, Normal]: 0 days, 10 hours, 39 minutes and 53.10 seconds
# Total training time for balancescale [none, Normal]: 0 days, 9 hours, 14 minutes and 9.60 seconds
# Total training time for breastcancerwisc [none, Normal]: 0 days, 11 hours, 3 minutes and 53.60 seconds
# Total training time for cardiotocography3clases [none, Normal]: 0 days, 3 hours, 5 minutes and 2.70 seconds
# Total training time for energyy1 [none, Normal]: 0 days, 4 hours, 59 minutes and 38.80 seconds
# Total training time for energyy2 [none, Normal]: 0 days, 7 hours, 20 minutes and 17.40 seconds
# Total training time for iris [none, Normal]: 0 days, 8 hours, 0 minutes and 4.60 seconds
# Total training time for mammographic [none, Normal]: 0 days, 9 hours, 40 minutes and 39.30 seconds
# Total training time for pendigits [none, Normal]: 0 days, 3 hours, 46 minutes and 43.90 seconds
# Total training time for seeds [none, Normal]: 0 days, 9 hours, 17 minutes and 30.70 seconds
# Total training time for tictactoe [none, Normal]: 0 days, 8 hours, 30 minutes and 46.70 seconds
# Total training time for vertebralcolumn2clases [none, Normal]: 0 days, 11 hours, 39 minutes and 0.80 seconds
# Total training time for vertebralcolumn3clases [none, Normal]: 0 days, 7 hours, 1 minutes and 13.80 seconds
# Total training time for acuteinflammation [none, Robust]: 0 days, 17 hours, 11 minutes and 45.20 seconds
# Total training time for balancescale [none, Robust]: 0 days, 16 hours, 4 minutes and 46.80 seconds
# Total training time for breastcancerwisc [none, Robust]: 0 days, 18 hours, 12 minutes and 28.60 seconds
# Total training time for cardiotocography3clases [none, Robust]: 0 days, 22 hours, 42 minutes and 20.60 seconds
# Total training time for energyy1 [none, Robust]: 1 days, 0 hours, 53 minutes and 31.40 seconds
# Total training time for energyy2 [none, Robust]: 1 days, 0 hours, 55 minutes and 7.30 seconds
# Total training time for iris [none, Robust]: 0 days, 19 hours, 29 minutes and 22.10 seconds
# Total training time for mammographic [none, Robust]: 0 days, 20 hours, 30 minutes and 8.50 seconds
# Total training time for pendigits [none, Robust]: 1 days, 8 hours, 15 minutes and 14.60 seconds
# Total training time for seeds [none, Robust]: 0 days, 21 hours, 52 minutes and 18.90 seconds
# Total training time for tictactoe [none, Robust]: 0 days, 20 hours, 42 minutes and 2.20 seconds
# Total training time for vertebralcolumn2clases [none, Robust]: 0 days, 17 hours, 45 minutes and 0.60 seconds
# Total training time for vertebralcolumn3clases [none, Robust]: 0 days, 16 hours, 45 minutes and 8.30 seconds
# Total training time for acuteinflammation [none, Mixed]: 1 days, 21 hours, 48 minutes and 3.50 seconds
# Total training time for balancescale [none, Mixed]: 1 days, 20 hours, 53 minutes and 27.20 seconds
# Total training time for breastcancerwisc [none, Mixed]: 1 days, 22 hours, 54 minutes and 50.60 seconds
# Total training time for cardiotocography3clases [none, Mixed]: 2 days, 5 hours, 27 minutes and 1.50 seconds
# Total training time for energyy1 [none, Mixed]: 2 days, 6 hours, 57 minutes and 57.40 seconds
# Total training time for energyy2 [none, Mixed]: 2 days, 3 hours, 41 minutes and 30.70 seconds
# Total training time for iris [none, Mixed]: 1 days, 23 hours, 28 minutes and 56.90 seconds
# Total training time for mammographic [none, Mixed]: 1 days, 22 hours, 46 minutes and 43.40 seconds
# Total training time for pendigits [none, Mixed]: 2 days, 20 hours, 46 minutes and 24.30 seconds
# Total training time for seeds [none, Mixed]: 1 days, 20 hours, 29 minutes and 45.10 seconds
# Total training time for tictactoe [none, Mixed]: 1 days, 20 hours, 35 minutes and 30.90 seconds
# Total training time for vertebralcolumn2clases [none, Mixed]: 1 days, 14 hours, 52 minutes and 19.80 seconds
# Total training time for vertebralcolumn3clases [none, Mixed]: 1 days, 13 hours, 37 minutes and 56.40 seconds

# %%
results
# Out:
# [{'Normal_tanh': 32065.699999999997,
#   'dataset': 'acuteinflammation',
#   'total_seconds': 32065.699999999997},
#  {'Normal_tanh': 30330.300000000007,
#   'dataset': 'balancescale',
#   'total_seconds': 30330.300000000007},
#  {'Normal_tanh': 35676.8,
#   'dataset': 'breastcancerwisc',
#   'total_seconds': 35676.8},
#  {'Normal_tanh': 51576.3,
#   'dataset': 'cardiotocography3clases',
#   'total_seconds': 51576.3},
#  {'Normal_tanh': 38679.2, 'dataset': 'energyy1', 'total_seconds': 38679.2},
#  {'Normal_tanh': 38395.100000000006,
#   'dataset': 'energyy2',
#   'total_seconds': 38395.100000000006},
#  {'Normal_tanh': 30209.399999999998,
#   'dataset': 'iris',
#   'total_seconds': 30209.399999999998},
#  {'Normal_tanh': 32700.999999999996,
#   'dataset': 'mammographic',
#   'total_seconds': 32700.999999999996},
#  {'Normal_tanh': 58160.799999999996,
#   'dataset': 'pendigits',
#   'total_seconds': 58160.799999999996},
#  {'Normal_tanh': 34184.6, 'dataset': 'seeds', 'total_seconds': 34184.6},
#  {'Normal_tanh': 39151.3, 'dataset': 'tictactoe', 'total_seconds': 39151.3},
#  {'Normal_tanh': 32045.2,
#   'dataset': 'vertebralcolumn2clases',
#   'total_seconds': 32045.2},
#  {'Normal_tanh': 27823.999999999993,
#   'dataset': 'vertebralcolumn3clases',
#   'total_seconds': 27823.999999999993},
#  {'Robust_tanh': 34640.40000000001,
#   'dataset': 'acuteinflammation',
#   'total_seconds': 34640.40000000001},
#  {'Robust_tanh': 31258.5, 'dataset': 'balancescale', 'total_seconds': 31258.5},
#  {'Robust_tanh': 40274.6,
#   'dataset': 'breastcancerwisc',
#   'total_seconds': 40274.6},
#  {'Robust_tanh': 52537.49999999999,
#   'dataset': 'cardiotocography3clases',
#   'total_seconds': 52537.49999999999},
#  {'Robust_tanh': 40517.299999999996,
#   'dataset': 'energyy1',
#   'total_seconds': 40517.299999999996},
#  {'Robust_tanh': 39985.4, 'dataset': 'energyy2', 'total_seconds': 39985.4},
#  {'Robust_tanh': 29108.100000000002,
#   'dataset': 'iris',
#   'total_seconds': 29108.100000000002},
#  {'Robust_tanh': 28871.500000000004,
#   'dataset': 'mammographic',
#   'total_seconds': 28871.500000000004},
#  {'Robust_tanh': 75858.1, 'dataset': 'pendigits', 'total_seconds': 75858.1},
#  {'Robust_tanh': 34627.90000000001,
#   'dataset': 'seeds',
#   'total_seconds': 34627.90000000001},
#  {'Robust_tanh': 37331.5, 'dataset': 'tictactoe', 'total_seconds': 37331.5},
#  {'Robust_tanh': 33396.2,
#   'dataset': 'vertebralcolumn2clases',
#   'total_seconds': 33396.2},
#  {'Robust_tanh': 26305.000000000004,
#   'dataset': 'vertebralcolumn3clases',
#   'total_seconds': 26305.000000000004},
#  {'Mixed_tanh': 0, 'dataset': 'acuteinflammation', 'total_seconds': 0},
#  {'Mixed_tanh': 0, 'dataset': 'balancescale', 'total_seconds': 0},
#  {'Mixed_tanh': 0, 'dataset': 'breastcancerwisc', 'total_seconds': 0},
#  {'Mixed_tanh': 0, 'dataset': 'cardiotocography3clases', 'total_seconds': 0},
#  {'Mixed_tanh': 0, 'dataset': 'energyy1', 'total_seconds': 0},
#  {'Mixed_tanh': 0, 'dataset': 'energyy2', 'total_seconds': 0},
#  {'Mixed_tanh': 0, 'dataset': 'iris', 'total_seconds': 0},
#  {'Mixed_tanh': 0, 'dataset': 'mammographic', 'total_seconds': 0},
#  {'Mixed_tanh': 0, 'dataset': 'pendigits', 'total_seconds': 0},
#  {'Mixed_tanh': 0, 'dataset': 'seeds', 'total_seconds': 0},
#  {'Mixed_tanh': 0, 'dataset': 'tictactoe', 'total_seconds': 0},
#  {'Mixed_tanh': 0, 'dataset': 'vertebralcolumn2clases', 'total_seconds': 0},
#  {'Mixed_tanh': 0, 'dataset': 'vertebralcolumn3clases', 'total_seconds': 0},
#  {'Normal_relu': 36941.2,
#   'dataset': 'acuteinflammation',
#   'total_seconds': 36941.2},
#  {'Normal_relu': 36323.4, 'dataset': 'balancescale', 'total_seconds': 36323.4},
#  {'Normal_relu': 50213.8,
#   'dataset': 'breastcancerwisc',
#   'total_seconds': 50213.8},
#  {'Normal_relu': 65628.09999999999,
#   'dataset': 'cardiotocography3clases',
#   'total_seconds': 65628.09999999999},
#  {'Normal_relu': 48547.19999999999,
#   'dataset': 'energyy1',
#   'total_seconds': 48547.19999999999},
#  {'Normal_relu': 47391.299999999996,
#   'dataset': 'energyy2',
#   'total_seconds': 47391.299999999996},
#  {'Normal_relu': 36546.200000000004,
#   'dataset': 'iris',
#   'total_seconds': 36546.200000000004},
#  {'Normal_relu': 37023.7, 'dataset': 'mammographic', 'total_seconds': 37023.7},
#  {'Normal_relu': 76712.99999999999,
#   'dataset': 'pendigits',
#   'total_seconds': 76712.99999999999},
#  {'Normal_relu': 40821.8, 'dataset': 'seeds', 'total_seconds': 40821.8},
#  {'Normal_relu': 41765.69999999999,
#   'dataset': 'tictactoe',
#   'total_seconds': 41765.69999999999},
#  {'Normal_relu': 40338.600000000006,
#   'dataset': 'vertebralcolumn2clases',
#   'total_seconds': 40338.600000000006},
#  {'Normal_relu': 33176.0,
#   'dataset': 'vertebralcolumn3clases',
#   'total_seconds': 33176.0},
#  {'Robust_relu': 37607.4,
#   'dataset': 'acuteinflammation',
#   'total_seconds': 37607.4},
#  {'Robust_relu': 40492.4, 'dataset': 'balancescale', 'total_seconds': 40492.4},
#  {'Robust_relu': 53371.6,
#   'dataset': 'breastcancerwisc',
#   'total_seconds': 53371.6},
#  {'Robust_relu': 65763.0,
#   'dataset': 'cardiotocography3clases',
#   'total_seconds': 65763.0},
#  {'Robust_relu': 51377.70000000001,
#   'dataset': 'energyy1',
#   'total_seconds': 51377.70000000001},
#  {'Robust_relu': 51135.50000000001,
#   'dataset': 'energyy2',
#   'total_seconds': 51135.50000000001},
#  {'Robust_relu': 39464.5, 'dataset': 'iris', 'total_seconds': 39464.5},
#  {'Robust_relu': 39220.899999999994,
#   'dataset': 'mammographic',
#   'total_seconds': 39220.899999999994},
#  {'Robust_relu': 75711.90000000001,
#   'dataset': 'pendigits',
#   'total_seconds': 75711.90000000001},
#  {'Robust_relu': 42022.7, 'dataset': 'seeds', 'total_seconds': 42022.7},
#  {'Robust_relu': 49454.0, 'dataset': 'tictactoe', 'total_seconds': 49454.0},
#  {'Robust_relu': 43283.5,
#   'dataset': 'vertebralcolumn2clases',
#   'total_seconds': 43283.5},
#  {'Robust_relu': 35799.200000000004,
#   'dataset': 'vertebralcolumn3clases',
#   'total_seconds': 35799.200000000004},
#  {'Mixed_relu': 0, 'dataset': 'acuteinflammation', 'total_seconds': 0},
#  {'Mixed_relu': 0, 'dataset': 'balancescale', 'total_seconds': 0},
#  {'Mixed_relu': 0, 'dataset': 'breastcancerwisc', 'total_seconds': 0},
#  {'Mixed_relu': 0, 'dataset': 'cardiotocography3clases', 'total_seconds': 0},
#  {'Mixed_relu': 0, 'dataset': 'energyy1', 'total_seconds': 0},
#  {'Mixed_relu': 0, 'dataset': 'energyy2', 'total_seconds': 0},
#  {'Mixed_relu': 0, 'dataset': 'iris', 'total_seconds': 0},
#  {'Mixed_relu': 0, 'dataset': 'mammographic', 'total_seconds': 0},
#  {'Mixed_relu': 0, 'dataset': 'pendigits', 'total_seconds': 0},
#  {'Mixed_relu': 0, 'dataset': 'seeds', 'total_seconds': 0},
#  {'Mixed_relu': 0, 'dataset': 'tictactoe', 'total_seconds': 0},
#  {'Mixed_relu': 0, 'dataset': 'vertebralcolumn2clases', 'total_seconds': 0},
#  {'Mixed_relu': 0, 'dataset': 'vertebralcolumn3clases', 'total_seconds': 0},
#  {'Normal_sigmoid': 27712.7,
#   'dataset': 'acuteinflammation',
#   'total_seconds': 27712.7},
#  {'Normal_sigmoid': 29397.90000000001,
#   'dataset': 'balancescale',
#   'total_seconds': 29397.90000000001},
#  {'Normal_sigmoid': 33316.0,
#   'dataset': 'breastcancerwisc',
#   'total_seconds': 33316.0},
#  {'Normal_sigmoid': 56598.3,
#   'dataset': 'cardiotocography3clases',
#   'total_seconds': 56598.3},
#  {'Normal_sigmoid': 38639.6, 'dataset': 'energyy1', 'total_seconds': 38639.6},
#  {'Normal_sigmoid': 38034.3, 'dataset': 'energyy2', 'total_seconds': 38034.3},
#  {'Normal_sigmoid': 27520.800000000003,
#   'dataset': 'iris',
#   'total_seconds': 27520.800000000003},
#  {'Normal_sigmoid': 31531.099999999995,
#   'dataset': 'mammographic',
#   'total_seconds': 31531.099999999995},
#  {'Normal_sigmoid': 59768.100000000006,
#   'dataset': 'pendigits',
#   'total_seconds': 59768.100000000006},
#  {'Normal_sigmoid': 32647.699999999997,
#   'dataset': 'seeds',
#   'total_seconds': 32647.699999999997},
#  {'Normal_sigmoid': 32153.999999999996,
#   'dataset': 'tictactoe',
#   'total_seconds': 32153.999999999996},
#  {'Normal_sigmoid': 32372.800000000003,
#   'dataset': 'vertebralcolumn2clases',
#   'total_seconds': 32372.800000000003},
#  {'Normal_sigmoid': 28244.999999999993,
#   'dataset': 'vertebralcolumn3clases',
#   'total_seconds': 28244.999999999993},
#  {'Robust_sigmoid': 29236.100000000002,
#   'dataset': 'acuteinflammation',
#   'total_seconds': 29236.100000000002},
#  {'Robust_sigmoid': 29315.999999999996,
#   'dataset': 'balancescale',
#   'total_seconds': 29315.999999999996},
#  {'Robust_sigmoid': 38718.9,
#   'dataset': 'breastcancerwisc',
#   'total_seconds': 38718.9},
#  {'Robust_sigmoid': 53350.700000000004,
#   'dataset': 'cardiotocography3clases',
#   'total_seconds': 53350.700000000004},
#  {'Robust_sigmoid': 39698.59999999999,
#   'dataset': 'energyy1',
#   'total_seconds': 39698.59999999999},
#  {'Robust_sigmoid': 40331.1, 'dataset': 'energyy2', 'total_seconds': 40331.1},
#  {'Robust_sigmoid': 30674.100000000006,
#   'dataset': 'iris',
#   'total_seconds': 30674.100000000006},
#  {'Robust_sigmoid': 33431.799999999996,
#   'dataset': 'mammographic',
#   'total_seconds': 33431.799999999996},
#  {'Robust_sigmoid': 69470.9, 'dataset': 'pendigits', 'total_seconds': 69470.9},
#  {'Robust_sigmoid': 33166.00000000001,
#   'dataset': 'seeds',
#   'total_seconds': 33166.00000000001},
#  {'Robust_sigmoid': 35571.299999999996,
#   'dataset': 'tictactoe',
#   'total_seconds': 35571.299999999996},
#  {'Robust_sigmoid': 29530.3,
#   'dataset': 'vertebralcolumn2clases',
#   'total_seconds': 29530.3},
#  {'Robust_sigmoid': 28660.7,
#   'dataset': 'vertebralcolumn3clases',
#   'total_seconds': 28660.7},
#  {'Mixed_sigmoid': 0, 'dataset': 'acuteinflammation', 'total_seconds': 0},
#  {'Mixed_sigmoid': 0, 'dataset': 'balancescale', 'total_seconds': 0},
#  {'Mixed_sigmoid': 0, 'dataset': 'breastcancerwisc', 'total_seconds': 0},
#  {'Mixed_sigmoid': 0,
#   'dataset': 'cardiotocography3clases',
#   'total_seconds': 0},
#  {'Mixed_sigmoid': 0, 'dataset': 'energyy1', 'total_seconds': 0},
#  {'Mixed_sigmoid': 0, 'dataset': 'energyy2', 'total_seconds': 0},
#  {'Mixed_sigmoid': 0, 'dataset': 'iris', 'total_seconds': 0},
#  {'Mixed_sigmoid': 0, 'dataset': 'mammographic', 'total_seconds': 0},
#  {'Mixed_sigmoid': 0, 'dataset': 'pendigits', 'total_seconds': 0},
#  {'Mixed_sigmoid': 0, 'dataset': 'seeds', 'total_seconds': 0},
#  {'Mixed_sigmoid': 0, 'dataset': 'tictactoe', 'total_seconds': 0},
#  {'Mixed_sigmoid': 0, 'dataset': 'vertebralcolumn2clases', 'total_seconds': 0},
#  {'Mixed_sigmoid': 0, 'dataset': 'vertebralcolumn3clases', 'total_seconds': 0},
#  {'Normal_cr': 31803.799999999996,
#   'dataset': 'acuteinflammation',
#   'total_seconds': 31803.799999999996},
#  {'Normal_cr': 33885.4, 'dataset': 'balancescale', 'total_seconds': 33885.4},
#  {'Normal_cr': 38205.50000000001,
#   'dataset': 'breastcancerwisc',
#   'total_seconds': 38205.50000000001},
#  {'Normal_cr': 61862.29999999999,
#   'dataset': 'cardiotocography3clases',
#   'total_seconds': 61862.29999999999},
#  {'Normal_cr': 43736.299999999996,
#   'dataset': 'energyy1',
#   'total_seconds': 43736.299999999996},
#  {'Normal_cr': 44841.99999999999,
#   'dataset': 'energyy2',
#   'total_seconds': 44841.99999999999},
#  {'Normal_cr': 35970.8, 'dataset': 'iris', 'total_seconds': 35970.8},
#  {'Normal_cr': 29597.100000000002,
#   'dataset': 'mammographic',
#   'total_seconds': 29597.100000000002},
#  {'Normal_cr': 74694.3, 'dataset': 'pendigits', 'total_seconds': 74694.3},
#  {'Normal_cr': 36596.299999999996,
#   'dataset': 'seeds',
#   'total_seconds': 36596.299999999996},
#  {'Normal_cr': 36947.0, 'dataset': 'tictactoe', 'total_seconds': 36947.0},
#  {'Normal_cr': 29881.600000000002,
#   'dataset': 'vertebralcolumn2clases',
#   'total_seconds': 29881.600000000002},
#  {'Normal_cr': 32866.0,
#   'dataset': 'vertebralcolumn3clases',
#   'total_seconds': 32866.0},
#  {'Robust_cr': 36228.0,
#   'dataset': 'acuteinflammation',
#   'total_seconds': 36228.0},
#  {'Robust_cr': 34789.899999999994,
#   'dataset': 'balancescale',
#   'total_seconds': 34789.899999999994},
#  {'Robust_cr': 48950.799999999996,
#   'dataset': 'breastcancerwisc',
#   'total_seconds': 48950.799999999996},
#  {'Robust_cr': 61555.799999999996,
#   'dataset': 'cardiotocography3clases',
#   'total_seconds': 61555.799999999996},
#  {'Robust_cr': 50412.00000000001,
#   'dataset': 'energyy1',
#   'total_seconds': 50412.00000000001},
#  {'Robust_cr': 48149.50000000001,
#   'dataset': 'energyy2',
#   'total_seconds': 48149.50000000001},
#  {'Robust_cr': 40913.600000000006,
#   'dataset': 'iris',
#   'total_seconds': 40913.600000000006},
#  {'Robust_cr': 32852.600000000006,
#   'dataset': 'mammographic',
#   'total_seconds': 32852.600000000006},
#  {'Robust_cr': 90334.2, 'dataset': 'pendigits', 'total_seconds': 90334.2},
#  {'Robust_cr': 39537.200000000004,
#   'dataset': 'seeds',
#   'total_seconds': 39537.200000000004},
#  {'Robust_cr': 37613.799999999996,
#   'dataset': 'tictactoe',
#   'total_seconds': 37613.799999999996},
#  {'Robust_cr': 31637.9,
#   'dataset': 'vertebralcolumn2clases',
#   'total_seconds': 31637.9},
#  {'Robust_cr': 31566.400000000005,
#   'dataset': 'vertebralcolumn3clases',
#   'total_seconds': 31566.400000000005},
#  {'Mixed_cr': 0, 'dataset': 'acuteinflammation', 'total_seconds': 0},
#  {'Mixed_cr': 0, 'dataset': 'balancescale', 'total_seconds': 0},
#  {'Mixed_cr': 0, 'dataset': 'breastcancerwisc', 'total_seconds': 0},
#  {'Mixed_cr': 0, 'dataset': 'cardiotocography3clases', 'total_seconds': 0},
#  {'Mixed_cr': 0, 'dataset': 'energyy1', 'total_seconds': 0},
#  {'Mixed_cr': 0, 'dataset': 'energyy2', 'total_seconds': 0},
#  {'Mixed_cr': 0, 'dataset': 'iris', 'total_seconds': 0},
#  {'Mixed_cr': 0, 'dataset': 'mammographic', 'total_seconds': 0},
#  {'Mixed_cr': 0, 'dataset': 'pendigits', 'total_seconds': 0},
#  {'Mixed_cr': 0, 'dataset': 'seeds', 'total_seconds': 0},
#  {'Mixed_cr': 0, 'dataset': 'tictactoe', 'total_seconds': 0},
#  {'Mixed_cr': 0, 'dataset': 'vertebralcolumn2clases', 'total_seconds': 0},
#  {'Mixed_cr': 0, 'dataset': 'vertebralcolumn3clases', 'total_seconds': 0},
#  {'Normal_none': 38393.09999999999,
#   'dataset': 'acuteinflammation',
#   'total_seconds': 38393.09999999999},
#  {'Normal_none': 33249.6, 'dataset': 'balancescale', 'total_seconds': 33249.6},
#  {'Normal_none': 39833.6,
#   'dataset': 'breastcancerwisc',
#   'total_seconds': 39833.6},
#  {'Normal_none': 11102.7,
#   'dataset': 'cardiotocography3clases',
#   'total_seconds': 11102.7},
#  {'Normal_none': 17978.800000000003,
#   'dataset': 'energyy1',
#   'total_seconds': 17978.800000000003},
#  {'Normal_none': 26417.399999999998,
#   'dataset': 'energyy2',
#   'total_seconds': 26417.399999999998},
#  {'Normal_none': 28804.600000000002,
#   'dataset': 'iris',
#   'total_seconds': 28804.600000000002},
#  {'Normal_none': 34839.3, 'dataset': 'mammographic', 'total_seconds': 34839.3},
#  {'Normal_none': 13603.899999999998,
#   'dataset': 'pendigits',
#   'total_seconds': 13603.899999999998},
#  {'Normal_none': 33450.700000000004,
#   'dataset': 'seeds',
#   'total_seconds': 33450.700000000004},
#  {'Normal_none': 30646.699999999997,
#   'dataset': 'tictactoe',
#   'total_seconds': 30646.699999999997},
#  {'Normal_none': 41940.799999999996,
#   'dataset': 'vertebralcolumn2clases',
#   'total_seconds': 41940.799999999996},
#  {'Normal_none': 25273.8,
#   'dataset': 'vertebralcolumn3clases',
#   'total_seconds': 25273.8},
#  {'Robust_none': 61905.2,
#   'dataset': 'acuteinflammation',
#   'total_seconds': 61905.2},
#  {'Robust_none': 57886.8, 'dataset': 'balancescale', 'total_seconds': 57886.8},
#  {'Robust_none': 65548.59999999999,
#   'dataset': 'breastcancerwisc',
#   'total_seconds': 65548.59999999999},
#  {'Robust_none': 81740.59999999999,
#   'dataset': 'cardiotocography3clases',
#   'total_seconds': 81740.59999999999},
#  {'Robust_none': 89611.4, 'dataset': 'energyy1', 'total_seconds': 89611.4},
#  {'Robust_none': 89707.29999999999,
#   'dataset': 'energyy2',
#   'total_seconds': 89707.29999999999},
#  {'Robust_none': 70162.09999999999,
#   'dataset': 'iris',
#   'total_seconds': 70162.09999999999},
#  {'Robust_none': 73808.5, 'dataset': 'mammographic', 'total_seconds': 73808.5},
#  {'Robust_none': 116114.6, 'dataset': 'pendigits', 'total_seconds': 116114.6},
#  {'Robust_none': 78738.9, 'dataset': 'seeds', 'total_seconds': 78738.9},
#  {'Robust_none': 74522.20000000001,
#   'dataset': 'tictactoe',
#   'total_seconds': 74522.20000000001},
#  {'Robust_none': 63900.59999999999,
#   'dataset': 'vertebralcolumn2clases',
#   'total_seconds': 63900.59999999999},
#  {'Robust_none': 60308.299999999996,
#   'dataset': 'vertebralcolumn3clases',
#   'total_seconds': 60308.299999999996},
#  {'Mixed_none': 164883.5,
#   'dataset': 'acuteinflammation',
#   'total_seconds': 164883.5},
#  {'Mixed_none': 161607.2,
#   'dataset': 'balancescale',
#   'total_seconds': 161607.2},
#  {'Mixed_none': 168890.6,
#   'dataset': 'breastcancerwisc',
#   'total_seconds': 168890.6},
#  {'Mixed_none': 192421.49999999997,
#   'dataset': 'cardiotocography3clases',
#   'total_seconds': 192421.49999999997},
#  {'Mixed_none': 197877.4, 'dataset': 'energyy1', 'total_seconds': 197877.4},
#  {'Mixed_none': 186090.69999999998,
#   'dataset': 'energyy2',
#   'total_seconds': 186090.69999999998},
#  {'Mixed_none': 170936.90000000002,
#   'dataset': 'iris',
#   'total_seconds': 170936.90000000002},
#  {'Mixed_none': 168403.4,
#   'dataset': 'mammographic',
#   'total_seconds': 168403.4},
#  {'Mixed_none': 247584.30000000002,
#   'dataset': 'pendigits',
#   'total_seconds': 247584.30000000002},
#  {'Mixed_none': 160185.1, 'dataset': 'seeds', 'total_seconds': 160185.1},
#  {'Mixed_none': 160530.90000000002,
#   'dataset': 'tictactoe',
#   'total_seconds': 160530.90000000002},
#  {'Mixed_none': 139939.80000000002,
#   'dataset': 'vertebralcolumn2clases',
#   'total_seconds': 139939.80000000002},
#  {'Mixed_none': 135476.40000000002,
#   'dataset': 'vertebralcolumn3clases',
#   'total_seconds': 135476.40000000002}]

# %%
import pandas as pd

# Suppose 'results' is your list of dictionaries.
# We want to create a new list of dictionaries where each dictionary looks like:
# {'dataset': <dataset>, 'condition': <condition>, 'total_seconds': <value>}
new_results = []
for d in results:
    # Find the key that is not 'dataset' or 'total_seconds'
    condition = None
    for k in d:
        if k not in ['dataset', 'total_seconds']:
            condition = k
            break
    if condition is not None:
        new_results.append({
            'dataset': d['dataset'],
            'condition': condition,
            'total_seconds': d[condition]
        })

# Convert the new list to a DataFrame
df_long = pd.DataFrame(new_results)

# Now pivot the DataFrame:
pivot_df = df_long.pivot(index='dataset', columns='condition', values='total_seconds')

# Optional: sort the columns for clarity
pivot_df = pivot_df.sort_index(axis=1)

# Save the pivoted DataFrame to Excel
pivot_df.to_excel("training_times_pivot.xlsx", index=True)
print("Pivoted results saved to training_times_pivot.xlsx")
# Out:
# Pivoted results saved to training_times_pivot.xlsx

# %%
import pandas as pd
# Convert results to DataFrame.
df = pd.DataFrame(results)

columns = []
for a in acts:
    for t in types:
        columns.append(f'{t}_{a}')

# Pivot the DataFrame: rows = dataset, columns = condition, values = total_seconds.
pivot_df = df.pivot(index='dataset', columns=columns, values='total_seconds')


# Optionally sort the columns.
# pivot_df = pivot_df.sort_index(axis=1)

# Save the pivot table to an Excel file.
pivot_df.to_excel("training_times_pivot.xlsx")
print("Pivoted results saved to training_times_pivot.xlsx")
# Out:
# Pivoted results saved to training_times_pivot.xlsx

# %%
import re
import os

def calculate_total_training_time(log_file_path):
    """
    Reads the log file, finds lines with 'Epoch: X' and 'Epoch time: Y',
    and computes total training time *assuming* 'Epoch time: Y' is
    the average time per epoch for the last (X - previous_epoch) epochs.
    """
    total_time = 0.0
    # This regex looks for a line containing something like:
    # | Epoch:    50 | Train loss: ... | Epoch time: 0.2 |
    pattern = re.compile(r'\|\s*Epoch:\s*(\d+)\s*\|.*Epoch time:\s+([\d.]+)')
    
    prev_epoch = None
    with open(log_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            match = pattern.search(line)
            if match:
                current_epoch = int(match.group(1))
                epoch_time_avg = float(match.group(2))  # average time per epoch (assumed)
                
                if prev_epoch is None:
                    # For the very first logged epoch, assume that the block covers all epochs from 0 up to current_epoch
                    block_size = current_epoch + 1  # e.g., epoch=50 implies epochs 0..50 inclusive => 51 epochs
                else:
                    # Otherwise, the block covers (prev_epoch+1) .. current_epoch
                    block_size = current_epoch - prev_epoch
                
                # Multiply average time by the block size
                total_time += epoch_time_avg * block_size
                prev_epoch = current_epoch

    return total_time

if __name__ == "__main__":
    ds = datasets[0]
    i = 0
    j = 0
    
    total = 0
    proposed_total_array = []
    # Replace 'path_to_your_log_file.log' with the actual path to your log file
    for i, ds in enumerate(datasets):
        total = 0
        for seed in range(0,1):
            log_path = f'/home/kit/itec/qc0876/projects/PowerAwarePNN/PowerAwarePNN/maincode/PowerAwareAugmentedLagrangian/log/{ds}_seed_{seed}_Penalty_AL_Factor_{int(target[0][i]):04d}.log'
            total_training_time = 0
            if os.path.exists(log_path):
                total_training_time = calculate_total_training_time(log_path)
            # else:
            #     print(f"Log file not found: {log_path}")
            # print(f"Total training time: {total_training_time} seconds")
            total += total_training_time
        proposed_total_array.append(total)
        minutes = int((total % 3600) // 60)
        seconds = total % 60
        days = int(total // 86400)
        hours = int((total % 86400) // 3600)
        print(f"Total training time for {ds}: {days} days, {hours} hours, {minutes} minutes and {seconds:.2f} seconds")
# Out:
# Total training time for data_acuteinflammation: 0 days, 0 hours, 20 minutes and 37.20 seconds
# Total training time for data_balancescale: 0 days, 9 hours, 13 minutes and 25.50 seconds
# Total training time for data_breastcancerwisc: 0 days, 0 hours, 33 minutes and 20.40 seconds
# Total training time for data_cardiotocography3clases: 0 days, 8 hours, 40 minutes and 16.20 seconds
# Total training time for data_energyy1: 0 days, 2 hours, 18 minutes and 30.60 seconds
# Total training time for data_energyy2: 0 days, 0 hours, 30 minutes and 15.40 seconds
# Total training time for data_iris: 0 days, 1 hours, 29 minutes and 0.40 seconds
# Total training time for data_mammographic: 0 days, 0 hours, 29 minutes and 0.40 seconds
# Total training time for data_pendigits: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Total training time for data_seeds: 0 days, 2 hours, 59 minutes and 20.40 seconds
# Total training time for data_tictactoe: 0 days, 3 hours, 8 minutes and 10.50 seconds
# Total training time for data_vertebralcolumn2clases: 0 days, 7 hours, 7 minutes and 45.40 seconds
# Total training time for data_vertebralcolumn3clases: 0 days, 0 hours, 39 minutes and 15.40 seconds

# %%
# Re-defining the data after environment reset


# Remove zeros from both lists
filtered_baseline = [b for b in baseline_total_array if b > 0]
filtered_proposed = [p for p in proposed_total_array if p > 0]

# Calculate average times
avg_baseline = sum(filtered_baseline) / len(filtered_baseline)
avg_proposed = sum(filtered_proposed) / len(filtered_proposed)

# Calculate reduction percentages
time_reduction = (1 - (avg_proposed / avg_baseline)) * 100
relative_time_ratio = avg_baseline / avg_proposed

avg_baseline, avg_proposed, time_reduction, relative_time_ratio
# Out:
# (498123.09166666795, 11244.816666666666, 97.74256266075867, 44.298018049797875)

# %%
498123.09166666795/60, 11244.816666666666/60
# Out:
# (8302.0515277778, 187.4136111111111)

# %%
2.264305555555555 + 187.4136111111111
# Out:
# 189.67791666666665

# %%
18576.175/60, 1089.141666666647/60
# Out:
# (309.60291666666666, 18.152361111110785)

# %%
import re
import os

def calculate_total_training_time(log_file_path):
    """
    Reads the log file, finds lines with 'Epoch: X' and 'Epoch time: Y',
    and computes total training time *assuming* 'Epoch time: Y' is
    the average time per epoch for the last (X - previous_epoch) epochs.
    """
    total_time = 0.0
    # This regex looks for a line containing something like:
    # | Epoch:    50 | Train loss: ... | Epoch time: 0.2 |
    pattern = re.compile(r'\|\s*Epoch:\s*(\d+)\s*\|.*Epoch time:\s+([\d.]+)')
    
    prev_epoch = None
    with open(log_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            match = pattern.search(line)
            if match:
                current_epoch = int(match.group(1))
                epoch_time_avg = float(match.group(2))  # average time per epoch (assumed)
                
                if prev_epoch is None:
                    # For the very first logged epoch, assume that the block covers all epochs from 0 up to current_epoch
                    block_size = current_epoch + 1  # e.g., epoch=50 implies epochs 0..50 inclusive => 51 epochs
                else:
                    # Otherwise, the block covers (prev_epoch+1) .. current_epoch
                    block_size = current_epoch - prev_epoch
                
                # Multiply average time by the block size
                total_time += epoch_time_avg * block_size
                prev_epoch = current_epoch

    return total_time

if __name__ == "__main__":
    ds = datasets[0]
    i = 0
    j = 0
    
    # Replace 'path_to_your_log_file.log' with the actual path to your log file
    mlflow_total_array = []
    for ds in datasets:
        total = 0
        log_path = f'/home/kit/itec/qc0876/projects/PowerAwarePNN/PowerAwarePNN/maincode/v3_MlflowPowerAwareAugmentedLagrangian/log/{ds}_seed_{0}_Penalty_AL_Factor_0000.log'
        total_training_time = 0
        if os.path.exists(log_path):
            total_training_time = calculate_total_training_time(log_path)
        else:
            print(f"Log file not found: {log_path}")
        # print(f"Total training time: {total_training_time} seconds")
        total += total_training_time
        mlflow_total_array.append(total)
        minutes = int((total % 3600) // 60)
        seconds = total % 60
        days = int(total // 86400)
        hours = int((total % 86400) // 3600)
        print(f"Total training time for {ds}: {days} days, {hours} hours, {minutes} minutes and {seconds:.2f} seconds")
# Out:
# Total training time for data_acuteinflammation: 0 days, 0 hours, 3 minutes and 10.30 seconds
# Total training time for data_balancescale: 0 days, 0 hours, 0 minutes and 30.30 seconds
# Total training time for data_breastcancerwisc: 0 days, 0 hours, 3 minutes and 10.40 seconds
# Total training time for data_cardiotocography3clases: 0 days, 0 hours, 0 minutes and 46.10 seconds
# Total training time for data_energyy1: 0 days, 0 hours, 3 minutes and 10.40 seconds
# Total training time for data_energyy2: 0 days, 0 hours, 3 minutes and 15.30 seconds
# Total training time for data_iris: 0 days, 0 hours, 2 minutes and 30.40 seconds
# Total training time for data_mammographic: 0 days, 0 hours, 3 minutes and 15.40 seconds
# Log file not found: /home/kit/itec/qc0876/projects/PowerAwarePNN/PowerAwarePNN/maincode/v3_MlflowPowerAwareAugmentedLagrangian/log/data_pendigits_seed_0_Penalty_AL_Factor_0000.log
# Total training time for data_pendigits: 0 days, 0 hours, 0 minutes and 0.00 seconds
# Total training time for data_seeds: 0 days, 0 hours, 3 minutes and 10.40 seconds
# Total training time for data_tictactoe: 0 days, 0 hours, 3 minutes and 10.40 seconds
# Total training time for data_vertebralcolumn2clases: 0 days, 0 hours, 0 minutes and 50.50 seconds
# Total training time for data_vertebralcolumn3clases: 0 days, 0 hours, 0 minutes and 10.40 seconds

# %%
# Re-defining the data after environment reset


# Remove zeros from both lists
filtered_mlflow = [b for b in mlflow_total_array if b > 0]

# Calculate average times
avg_mlflow = sum(filtered_mlflow) / len(filtered_mlflow)

avg_mlflow
# Out:
# 135.85833333333332

# %%
135.85833333333332/60
# Out:
# 2.264305555555555

# %%
import numpy as np
mean_total = avg_proposed
minutes = int((mean_total % 3600) // 60)
seconds = mean_total % 60
days = int(mean_total // 86400)
hours = int((mean_total % 86400) // 3600)
print(f"Total training time: {days} days, {hours} hours, {minutes} minutes and {seconds:.2f} seconds")
# Out:
# Total training time: 0 days, 0 hours, 18 minutes and 9.14 seconds

# %%
baseline_total_array, proposed_total_array
# Out:
# ([27681.300000000003,
#   11748.9,
#   15644.69999999998,
#   42854.00000000001,
#   22705.099999999988,
#   23772.300000000036,
#   13790.399999999996,
#   13965.899999999996,
#   0,
#   12467.299999999994,
#   15468.499999999993,
#   11545.899999999992,
#   11269.8],
#  [148.09999999999826,
#   1870.4999999998458,
#   85.09999999999948,
#   2162.6000000000236,
#   423.4000000000096,
#   133.89999999999986,
#   442.19999999999794,
#   1395.599999999886,
#   0,
#   2193.3000000001725,
#   1140.9999999999288,
#   1828.6999999999882,
#   1245.2999999999147])

# %%
baseline_total_array, proposed_total_array
# Out:
# ([27681.300000000003,
#   11748.9,
#   15644.69999999998,
#   42854.00000000001,
#   22705.099999999988,
#   23772.300000000036,
#   13790.399999999996,
#   13965.899999999996,
#   0,
#   12467.299999999994,
#   15468.499999999993,
#   11545.899999999992,
#   11269.8],
#  [148.09999999999826,
#   1870.4999999998458,
#   85.09999999999948,
#   2162.6000000000236,
#   423.4000000000096,
#   133.89999999999986,
#   442.19999999999794,
#   1395.599999999886,
#   0,
#   2193.3000000001725,
#   1140.9999999999288,
#   1828.6999999999882,
#   1245.2999999999147])

# %%
import re
from datetime import datetime

# log_file_path = '/home/kit/itec/qc0876/projects/PowerAwarePNN/PowerAwarePNN/maincode/PowerAwareAugmentedLagrangianHS/log/data_acuteinflammation_seed_0_Penalty_AL_Factor_0200.log'
baseline_total_array = []
for ds in datasets:
    total = 0
    for i in range(0,10):
        for j in range(0,100, 2):
            log_file_path = f'/home/kit/itec/qc0876/projects/PowerAwarePNN/PowerAwarePNN/maincode/PowerAwareBaselineHS/log/{ds}_seed_{i}_Penalty_power_Factor_{j}.log'
            # Read the log file
            if j == 58:
                continue
            try:
                with open(log_file_path, 'r') as file:
                    log_lines = file.readlines()
            except FileNotFoundError:
                print(f"Log file not found: {log_file_path}")
                continue
            

            # # Extract timestamps
            # timestamps = []
            # for line in log_lines:
            #     match = re.search(r'\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2},\d{3}', line)
            #     if match:
            #         timestamps.append(datetime.strptime(match.group(), '%Y-%m-%d %H:%M:%S,%f'))

            # # Calculate total training time considering multiple sessions
            # Calculate total training time considering multiple sessions
            total_training_time = 0
            start_time = None

            for line in log_lines:
                if "Training network on device: cpu." in line:
                    start_time = None  # Reset the start time
                if "Training was already finished." in line:
                    break
                else:
                    match = re.search(r'\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2},\d{3}', line)
                    if match:
                        current_time = datetime.strptime(match.group(), '%Y-%m-%d %H:%M:%S,%f')
                        if start_time is not None:
                            delta = (current_time - start_time).total_seconds()
                            total_training_time += delta
                        start_time = current_time
            # if timestamps:
            #     total_training_time = sum((timestamps[i] - timestamps[i - 1]).total_seconds() for i in range(1, len(timestamps)))
            #     print(f"Total training time: {total_training_time} seconds")
            # else:
            #     print("No timestamps found in the log file.")
            
            total += total_training_time
    minutes = int((total % 3600) // 60)
    seconds = total % 60
    days = int(total // 86400)
    hours = int((total % 86400) // 3600)
    print(f"Dataset: {ds}")
    print(f"Total training time: {days} days, {hours} hours, {minutes} minutes and {seconds:.2f} seconds")
    baseline_total_array.append(total)

# %%
baseline_total_array
# Out:
# [301452833.7129997,
#  305486729.6469996,
#  304775707.1890001,
#  297958326.01500016,
#  302933716.55099976,
#  290528358.09800017,
#  304824297.86800003,
#  305147568.0889999,
#  0,
#  305334140.53900003,
#  304810356.84200007,
#  305606236.00200003,
#  305684637.69299984]

# %%
import numpy as np
total = np.mean(baseline_total_array)
total = baseline_total_array[3]
total
# Out:
# 297958326.01500016

# %%
baseline_total_array
# Out:
# [989629.0160000001,
#  747224.6640000003,
#  842461.8100000002,
#  2910353.376000002,
#  302405801.02400017,
#  302047625.7630001,
#  304408486.0039997,
#  303469710.964,
#  0,
#  304245809.47299993,
#  303908692.1930001,
#  304897891.93299997,
#  303762392.625]

# %%
minutes = int((total % 3600) // 60)
seconds = total % 60
days = int(total // 86400)
hours = int((total % 86400) // 3600)
print(f"Total training time: {days} days, {hours} hours, {minutes} minutes and {seconds:.2f} seconds")
# Out:
# Total training time: 82766 hours 12 minutes 6.02 seconds
# Total training time: 3448 days, 14 hours, 12 minutes and 6.02 seconds

# %%
import re
from datetime import datetime

proposed_total_array = []
for i, ds in enumerate(datasets):
    log_file_path = f'/home/kit/itec/qc0876/projects/PowerAwarePNN/PowerAwarePNN/maincode/PowerAwareAugmentedLagrangianHS/log/{ds}_seed_0_Penalty_AL_Factor_{int(target[0][i]):04d}.log'
    # Read the log file
    try:
        with open(log_file_path, 'r') as file:
            log_lines = file.readlines()
    except FileNotFoundError:
        print(f"Log file not found: {log_file_path}")
        continue

    # Extract timestamps
    timestamps = []
    for line in log_lines:
        match = re.search(r'\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2},\d{3}', line)
        if match:
            timestamps.append(datetime.strptime(match.group(), '%Y-%m-%d %H:%M:%S,%f'))

    # Calculate total training time considering multiple sessions
    if timestamps:
        total_training_time = sum((timestamps[i] - timestamps[i - 1]).total_seconds() for i in range(1, len(timestamps)))
        print(f"Total training time: {total_training_time} seconds")
    else:
        print("No timestamps found in the log file.")
    proposed_total_array.append(total_training_time)
# Out:
# Total training time: 421906.49700000003 seconds
# Total training time: 752232.4269999999 seconds
# Total training time: 752193.716 seconds
# Total training time: 747732.25 seconds
# Total training time: 702051.645 seconds
# Total training time: 1031941.4550000001 seconds
# Total training time: 1032028.729 seconds
# Total training time: 1031941.9330000001 seconds
# Log file not found: /home/kit/itec/qc0876/projects/PowerAwarePNN/PowerAwarePNN/maincode/PowerAwareAugmentedLagrangianHS/log/data_pendigits_seed_0_Penalty_AL_Factor_0600.log
# Total training time: 1031907.553 seconds
# Total training time: 1031826.9 seconds
# Total training time: 1031823.306 seconds
# Total training time: 1031789.056 seconds

# %%
hours = int(total_training_time // 3600)
minutes = int((total_training_time % 3600) // 60)
seconds = total_training_time % 60
print(f"Total training time: {hours} hours {minutes} minutes {seconds:.2f} seconds")
days = int(total_training_time // 86400)
hours = int((total_training_time % 86400) // 3600)
print(f"Total training time: {days} days, {hours} hours, {minutes} minutes and {seconds:.2f} seconds")
# Out:
# Total training time: 117 hours 11 minutes 46.50 seconds
# Total training time: 4 days, 21 hours, 11 minutes and 46.50 seconds

# %%
import os
import sys
from pathlib import Path
sys.path.append(os.getcwd())
sys.path.append(str(Path(os.getcwd()).parent))
sys.path.append(os.path.join(os.getcwd(), 'utils'))
from configuration import *
import torch
import pprint
import pNN_Power_Aware as pNN
from utils import *

args = parser.parse_args([])
args = FormulateArgs(args)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 7
#       5 sys.path.append(str(Path(os.getcwd()).parent))
#       6 sys.path.append(os.path.join(os.getcwd(), 'utils'))
# ----> 7 from configuration import *
#       8 import torch
#       9 import pprint
#
# ModuleNotFoundError: No module named 'configuration'

# %%
file_path = "./maincode/PowerAwareBaselineHS/models/pNN_data_tictactoe_seed_4_Penalty_power_Factor_68_FT.model"

model_PT = torch.load(file_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 5
#       1 import torch
#       3 file_path = "./maincode/PowerAwareBaselineHS/models/pNN_data_tictactoe_seed_4_Penalty_power_Factor_68_FT.model"
# ----> 5 model_PT = torch.load(file_path)
#
# File ~/miniconda3/envs/train-model/lib/python3.12/site-packages/torch/serialization.py:1026, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1024             except RuntimeError as e:
#    1025                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1026         return _load(opened_zipfile,
#    1027                      map_location,
#    1028                      pickle_module,
#    1029                      overall_storage=overall_storage,
#    1030                      **pickle_load_args)
#    1031 if mmap:
#    1032     raise RuntimeError("mmap can only be used with files saved with "
#    1033                        "`torch.save(_use_new_zipfile_serialization=True), "
#    1034                        "please torch.save your checkpoint with this option in order to use mmap.")
#
# File ~/miniconda3/envs/train-model/lib/python3.12/site-packages/torch/serialization.py:1438, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1436 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1437 unpickler.persistent_load = persistent_load
# -> 1438 result = unpickler.load()
#    1440 torch._utils._validate_loaded_sparse_tensors()
#    1441 torch._C._log_api_usage_metadata(
#    1442     "torch.load.metadata", {"serialization_id": zip_file.serialization_id()}
#    1443 )
#
# File ~/miniconda3/envs/train-model/lib/python3.12/site-packages/torch/serialization.py:1431, in _load.<locals>.UnpicklerWrapper.find_class(self, mod_name, name)
#    1429         pass
#    1430 mod_name = load_module_mapping.get(mod_name, mod_name)
# -> 1431 return super().find_class(mod_name, name)
#
# ModuleNotFoundError: No module named 'pNN_Power_Aware'
